# %%
#loading basic required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a=pd.read_csv(r"C:\Users\SriSudha Lingala\Documents\Dhivya_(2-2)\PBL\Project_34\combined_dataset.csv")
a
# Out:
#                                                   domain   ranking  isIp  \
# 0                                   www.voting-yahoo.com  10000000     0
# 1             www.zvon.org/xxl/WSDL1.1/Output/index.html    194914     0
# 2      tecportais.com/file-security-update-infonfmati...  10000000     0
# 3                    bima.astro.umd.edu/nemo/linuxastro/      7001     0
# 4      huarui-tec.com/js/?us.battle.net/login/en/?ref...  10000000     0
# ...                                                  ...       ...   ...
# 95905                       www.freewebs.com/ryanrules2/      5001     0
# 95906    www.ireland-information.com/freecelticfonts.htm    230251     0
# 95907        www.clubtaunus.soroptimist.de/img/pro/e.php  10000000     0
# 95908          www.askmen.com/sports/business/index.html      2008     0
# 95909  xosothudo.com.vn/paypal.co.il/paypal.co.il.cgi...    771840     0
#
#        valid  activeDuration  urlLen  is@  isredirect  haveDash  domainLen  \
# 0          0               0      20    0           0         1         20
# 1          1            7305      42    0           0         0         12
# 2          0               0     155    0           0         0         14
# 3          0               0      35    0           0         0         18
# 4          1             730      79    0           0         1         14
# ...      ...             ...     ...  ...         ...       ...        ...
# 95905      1            8035      28    0           0         0         16
# 95906      1            8400      47    0           0         1         27
# 95907      0               0      43    0           0         0         29
# 95908      1            9862      41    0           0         0         14
# 95909      0               0     323    0           0         0         16
#
#        nosOfSubdomain  label
# 0                   2      1
# 1                   2      0
# 2                   1      1
# 3                   3      0
# 4                   1      1
# ...               ...    ...
# 95905               2      0
# 95906               2      0
# 95907               3      1
# 95908               2      0
# 95909               2      1
#
# [95910 rows x 12 columns]

# %%
#co-relation matrix

# %%
a.corr()
a.corr()['label'].sort_values()
# Out:
# activeDuration   -0.523114
# valid            -0.266774
# isIp              0.012811
# is@               0.039777
# isredirect        0.073247
# nosOfSubdomain    0.113249
# domainLen         0.231828
# haveDash          0.239623
# urlLen            0.396519
# ranking           0.516873
# label             1.000000
# Name: label, dtype: float64

# %%
#Preprocessing of dataset

# %%
a.describe()
# Out:
#             ranking          isIp         valid  activeDuration        urlLen  \
# count  9.591000e+04  95910.000000  95910.000000    95910.000000  95910.000000
# mean   6.118618e+06      0.000229      0.573892     3747.876144     69.327442
# std    4.835254e+06      0.015144      0.494512     3974.587188     69.740134
# min    1.000000e+00      0.000000      0.000000        0.000000      9.000000
# 25%    3.205600e+04      0.000000      0.000000        0.000000     31.000000
# 50%    1.000000e+07      0.000000      1.000000     2192.000000     44.000000
# 75%    1.000000e+07      0.000000      1.000000     7670.000000     78.000000
# max    1.000000e+07      1.000000      1.000000    15707.000000   2175.000000
#
#                 is@    isredirect      haveDash     domainLen  nosOfSubdomain  \
# count  95910.000000  95910.000000  95910.000000  95910.000000    95910.000000
# mean       0.002773      0.007444      0.157856     23.409061        2.387718
# std        0.052591      0.085960      0.364608     25.426852        2.140997
# min        0.000000      0.000000      0.000000      3.000000        0.000000
# 25%        0.000000      0.000000      0.000000     14.000000        2.000000
# 50%        0.000000      0.000000      0.000000     17.000000        2.000000
# 75%        0.000000      0.000000      0.000000     22.000000        2.000000
# max        1.000000      1.000000      1.000000    244.000000       34.000000
#
#               label
# count  95910.000000
# mean       0.582984
# std        0.493068
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000

# %%
a.shape
# Out:
# (95910, 12)

# %%
a.size
# Out:
# 1150920

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95910 entries, 0 to 95909
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   domain          95910 non-null  object
#  1   ranking         95910 non-null  int64
#  2   isIp            95910 non-null  int64
#  3   valid           95910 non-null  int64
#  4   activeDuration  95910 non-null  int64
#  5   urlLen          95910 non-null  int64
#  6   is@             95910 non-null  int64
#  7   isredirect      95910 non-null  int64
#  8   haveDash        95910 non-null  int64
#  9   domainLen       95910 non-null  int64
#  10  nosOfSubdomain  95910 non-null  int64
#  11  label           95910 non-null  int64
# dtypes: int64(11), object(1)
# memory usage: 8.8+ MB

# %%
a.head()
# Out:
#                                               domain   ranking  isIp  valid  \
# 0                               www.voting-yahoo.com  10000000     0      0
# 1         www.zvon.org/xxl/WSDL1.1/Output/index.html    194914     0      1
# 2  tecportais.com/file-security-update-infonfmati...  10000000     0      0
# 3                bima.astro.umd.edu/nemo/linuxastro/      7001     0      0
# 4  huarui-tec.com/js/?us.battle.net/login/en/?ref...  10000000     0      1
#
#    activeDuration  urlLen  is@  isredirect  haveDash  domainLen  \
# 0               0      20    0           0         1         20
# 1            7305      42    0           0         0         12
# 2               0     155    0           0         0         14
# 3               0      35    0           0         0         18
# 4             730      79    0           0         1         14
#
#    nosOfSubdomain  label
# 0               2      1
# 1               2      0
# 2               1      1
# 3               3      0
# 4               1      1

# %%
a.tail()
# Out:
#                                                   domain   ranking  isIp  \
# 95905                       www.freewebs.com/ryanrules2/      5001     0
# 95906    www.ireland-information.com/freecelticfonts.htm    230251     0
# 95907        www.clubtaunus.soroptimist.de/img/pro/e.php  10000000     0
# 95908          www.askmen.com/sports/business/index.html      2008     0
# 95909  xosothudo.com.vn/paypal.co.il/paypal.co.il.cgi...    771840     0
#
#        valid  activeDuration  urlLen  is@  isredirect  haveDash  domainLen  \
# 95905      1            8035      28    0           0         0         16
# 95906      1            8400      47    0           0         1         27
# 95907      0               0      43    0           0         0         29
# 95908      1            9862      41    0           0         0         14
# 95909      0               0     323    0           0         0         16
#
#        nosOfSubdomain  label
# 95905               2      0
# 95906               2      0
# 95907               3      1
# 95908               2      0
# 95909               2      1

# %%
a.isnull().sum()
# Out:
# domain            0
# ranking           0
# isIp              0
# valid             0
# activeDuration    0
# urlLen            0
# is@               0
# isredirect        0
# haveDash          0
# domainLen         0
# nosOfSubdomain    0
# label             0
# dtype: int64

# %%
print(a.corr())
# Out:
#                  ranking      isIp     valid  activeDuration    urlLen  \
# ranking         1.000000  0.002302 -0.271810       -0.462385  0.104733
# isIp            0.002302  1.000000  0.004698        0.000379 -0.001197
# valid          -0.271810  0.004698  1.000000        0.812531 -0.050022
# activeDuration -0.462385  0.000379  0.812531        1.000000 -0.133796
# urlLen          0.104733 -0.001197 -0.050022       -0.133796  1.000000
# is@             0.022798 -0.000799 -0.023917       -0.026034  0.017182
# isredirect      0.059468 -0.001312 -0.026677       -0.047993 -0.010021
# haveDash        0.103518 -0.002781 -0.128651       -0.150173  0.370280
# domainLen       0.154659  0.006634 -0.126793       -0.178393  0.497716
# nosOfSubdomain  0.105718  0.027164 -0.174061       -0.178431  0.346738
# label           0.516873  0.012811 -0.266774       -0.523114  0.396519
#
#                      is@  isredirect  haveDash  domainLen  nosOfSubdomain  \
# ranking         0.022798    0.059468  0.103518   0.154659        0.105718
# isIp           -0.000799   -0.001312 -0.002781   0.006634        0.027164
# valid          -0.023917   -0.026677 -0.128651  -0.126793       -0.174061
# activeDuration -0.026034   -0.047993 -0.150173  -0.178393       -0.178431
# urlLen          0.017182   -0.010021  0.370280   0.497716        0.346738
# is@             1.000000   -0.004567  0.000549  -0.002268       -0.003439
# isredirect     -0.004567    1.000000 -0.007222  -0.015948       -0.026618
# haveDash        0.000549   -0.007222  1.000000   0.365871        0.250143
# domainLen      -0.002268   -0.015948  0.365871   1.000000        0.863078
# nosOfSubdomain -0.003439   -0.026618  0.250143   0.863078        1.000000
# label           0.039777    0.073247  0.239623   0.231828        0.113249
#
#                    label
# ranking         0.516873
# isIp            0.012811
# valid          -0.266774
# activeDuration -0.523114
# urlLen          0.396519
# is@             0.039777
# isredirect      0.073247
# haveDash        0.239623
# domainLen       0.231828
# nosOfSubdomain  0.113249
# label           1.000000

# %%
import seaborn as sns
sns.countplot(x='label',data=a)
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %%
import seaborn as sns
sns.pairplot(a)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 15))
sns.heatmap(a.corr(),linewidths=.5)
# Out:
# <AxesSubplot:>

# %%
#Feature Selection

# %%
X= a.drop(['label', 'domain'], axis=1)
Y= a.label

# %%
#splitting of data

# %%
x_train, x_test, y_train, y_test = train_test_split(X,Y,test_size=0.40)

# %%
#Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
LogReg1=LogisticRegression()
LogReg1.fit(x_train,y_train)
y_pred_log = LogReg1.predict(x_test)
print("The accuracy Logistic Regression on testing data is: ",100.0 *accuracy_score(y_test,y_pred_log))
# Out:
# The accuracy Logistic Regression on testing data is:  72.50286727140028

# %%
#Support Vector Machine

# %%
from sklearn.svm import SVC   
from sklearn.metrics import accuracy_score
svc = SVC()
svc.fit(x_train,y_train)
y_pred_svc = svc.predict(x_test)
print("The accuracy SVM on testing data is: ",100.0 *accuracy_score(y_test,y_pred_svc))

# %%
#random Forest Classifer

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
RFClass = RandomForestClassifier()
RFClass.fit(x_train,y_train)
y_pred_rfc = RFClass.predict(x_test)
print("The accuracy Random forest classifier on testing data is: ",100.0 *accuracy_score(y_test,y_pred_rfc))
# Out:
# The accuracy Random forest classifier on testing data is:  95.20644354081952

# %%
print("The accuracy Logistic Regression on testing data is: ",100.0 *accuracy_score(y_test,y_pred_log))
print("The accuracy Random forest classifier on testing data is: ",100.0 *accuracy_score(y_test,y_pred_rfc))
print("The accuracy SVM on testing data is: ",100.0 *accuracy_score(y_test,y_pred_svc))
# Out:
# The accuracy Logistic Regression on testing data is:  72.50286727140028
# The accuracy Random forest classifier on testing data is:  95.20644354081952
# The accuracy SVM on testing data is:  76.42842247940777
